# %% [markdown]
# # IT Ticket Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/tickets.csv')
df.groupby('issue_type').size().plot(kind='bar')
plt.title('Tickets by Issue Type')
plt.show()
